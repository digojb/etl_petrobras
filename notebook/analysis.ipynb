# %%
path = '../data/dados_gasolina.json'
import pandas as pd
import json

# %%
with open(path) as f:
    data = json.load(f)

df = pd.json_normalize(data)
df
# Out:
#          Período de coleta Preço médio Brasil Preço médio Gasolina  \
# 0  15/03/2026 a 21/03/2026               6,65                 6,65
#
#   Distribuição Porcentagem Distribuição Custo do etanol anidro  \
# 0         1,61                     24,2                   0,99
#
#   Porcentagem Custo do etanol anidro  ICMS Porcentagem ICMS Imposto Federal  \
# 0                               14,9  1,57             23,6            0,68
#
#   Porcentagem Imposto Federal Parcela Petrobras Porcentagem Parcela Petrobras
# 0                        10,2               1,8                          27,1

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 13 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Período de coleta                   1 non-null      str
#  1   Preço médio Brasil                  1 non-null      str
#  2   Preço médio Gasolina                1 non-null      str
#  3   Distribuição                        1 non-null      str
#  4   Porcentagem Distribuição            1 non-null      str
#  5   Custo do etanol anidro              1 non-null      str
#  6   Porcentagem Custo do etanol anidro  1 non-null      str
#  7   ICMS                                1 non-null      str
#  8   Porcentagem ICMS                    1 non-null      str
#  9   Imposto Federal                     1 non-null      str
#  10  Porcentagem Imposto Federal         1 non-null      str
#  11  Parcela Petrobras                   1 non-null      str
# ...
